# %% [markdown]
# # ILQR Demo For N-dim System

# %%
# Import
import numpy as np
import matplotlib.pyplot as plt

import jax
import jax.numpy as jnp
from jax import grad, jit, vmap
from jax import random
from jax import jacobian, jacfwd, jacrev, hessian

# Random Setup
seed = 24234156
key = random.key(seed)

# Initialization
dt = 0.01

# %% [markdown]
# ## 1. 2d Pendulum System Dynamics
#
# a pendulum rotating on a vertical plane.
#
# - kinematic energy: $E = \frac{1}{2} m v^2$
# - potential energy: $P = \frac{1}{2} mgl sin\theta$
#
# State space system $$x = [\theta \quad \dot{\theta}]^T = [x_1 \quad x_2]^T$$
# then we have
# $$ \dot{x} = f(x,u) = [ x_2 \quad -\frac{l}{g} \cos{x_1} + \frac{1}{ml} u ]^T $$

# %% [markdown]
# ## 2. iLQR Implementation from Scratch

# %%
def f(x, u):
    g = 9.8 # m/s^2
    m = 2 # kg
    l = 0.1 # m
    
    x1, x2 = x
    dx1 = x2
    dx2 = - (g / l) * jnp.cos(x1) + (1 / (m * (l**2))) * u # (u**2)

    # x1, x2 = x
    # dx1 = x2
    # dx2 = u

    return jnp.array([dx1, dx2])

# %%
u = random.normal(key, (1,))

isinstance(u, jnp.ndarray)
# Out:
# True

# %%
x = random.normal(key, (2,))
print(x)
# Out:
# [0.49798056 0.09021932]

# %%
def fd_rk4(x, u):
    g = 9.8 # m/s^2
    m = 2 # kg
    l = 0.5 # m

    s1 = f(x,u)
    s2 = f( x+ dt/2*s1, u )
    s3 = f( x+ dt/2*s2, u )
    s4 = f( x+ dt*s3, u )
    x_next = x + dt/6 * ( s1 + 2 * s2 + 2 * s3 + s4 )
    
    return x_next

# %%
fd_rk4_x = jacfwd(fd_rk4, argnums=0)
fd_rk4_u = jacfwd(fd_rk4, argnums=1)
fd_rk4_xx = hessian(fd_rk4)

x = random.normal(key, (2,))
u = random.normal(key, ())

print(x)
print(u)

print("f wrt x is ",fd_rk4_x(x,u))
print("f wrt u is ",fd_rk4_u(x,u))

print("f wrt xx is ",fd_rk4_xx(x,u))
# Out:
# [0.49798056 0.09021932]
# 1.003158
# f wrt x is  [[1.0023414  0.0100078 ]
#  [0.46833697 1.0023401 ]]
# f wrt u is  [0.00250097 0.50038964]
# f wrt xx is  [[[4.30992618e-03 1.43580164e-05]
#   [1.43580155e-05 7.17480901e-08]]
#
#  [[8.63063455e-01 4.31398768e-03]
#   [4.31398768e-03 2.87482471e-05]]]

# %%
fd_rk4_xx = jacfwd(jacfwd(fd_rk4))
# fd_rk4_xx_grad = jacfwd(grad(fd_rk4)) # Gradient only defined for scalar-output functions
fd_rk4_xx_hessian = hessian(fd_rk4)

fd_rk4_uu = jacfwd(jacfwd(fd_rk4,argnums=1),argnums=1)
fd_rk4_uu_hessian = hessian(fd_rk4,argnums=1)

fd_rk4_ux = jacfwd(jacfwd(fd_rk4,argnums=1))
fd_rk4_ux_hessian = hessian(fd_rk4, argnums=[0,1])

x = random.normal(key, (2,))
u = random.normal(key, ())

print("f wrt xx is ",fd_rk4_xx(x,u))
# print("f wrt xx is grad",fd_rk4_xx_grad(x,u))
print("f wrt xx is hessian",fd_rk4_xx_hessian(x,u))

print("f wrt uu is ",fd_rk4_uu(x,u))
print("f wrt uu is hessian",fd_rk4_uu_hessian(x,u))

print("f wrt ux is ",fd_rk4_ux(x,u))
print("f wrt ux is hessian",fd_rk4_ux_hessian(x,u))
# Out:
# f wrt xx is  [[[4.3099257e-03 1.4358015e-05]
#   [1.4358015e-05 7.1748083e-08]]
#
#  [[8.6306345e-01 4.3139877e-03]
#   [4.3139877e-03 2.8748245e-05]]]
# f wrt xx is hessian [[[4.30992618e-03 1.43580164e-05]
#   [1.43580155e-05 7.17480901e-08]]
#
#  [[8.63063455e-01 4.31398768e-03]
#   [4.31398768e-03 2.87482471e-05]]]
# f wrt uu is  [2.2426754e-09 1.3458225e-06]
# f wrt uu is hessian [2.2426754e-09 1.3458224e-06]
# f wrt ux is  [[1.7962398e-06 8.9707015e-09]
#  [7.1900367e-04 5.3874937e-06]]
# f wrt ux is hessian ((Array([[[4.30992618e-03, 1.43580164e-05],
#         [1.43580155e-05, 7.17480901e-08]],
#
#        [[8.63063455e-01, 4.31398768e-03],
#         [4.31398768e-03, 2.87482471e-05]]], dtype=float32), Array([[1.7962399e-06, 8.9707015e-09],
#        [7.1900373e-04, 5.3874937e-06]], dtype=float32)), (Array([[1.7962398e-06, 8.9707015e-09],
#        [7.1900367e-04, 5.3874937e-06]], dtype=float32), Array([2.2426754e-09, 1.3458224e-06], dtype=float32)))

# %%
fd_rk4_uu = hessian(fd_rk4, argnums=1)
x = random.normal(key, (2,))
u = random.normal(key, ())
print("f wrt uu is ",fd_rk4_uu(x,u))
# Out:
# f wrt uu is  [2.2426754e-09 1.3458224e-06]

# %%
def fd_euler(x, u):
    g = 9.8 # m/s^2
    m = 2 # kg
    l = 0.5 # m

    x_next = x + dt * f(x,u)
    
    return x_next

# %%
def forward_pass(x_nor, x0, u):
    # x = jnp.zeros(T+1)  
    # du = jnp.zeros(T)

    x = np.zeros((T+1,nx))  
    du = np.zeros(T)
   
    x[0] = x0
    
    for t in range(T):
        du[t] = k[t] + K[t] @ (x[t] - x_nor[t])
        # u[t] += du[t]
        u = u.at[t].set(u[t]+du[t])

        # linear rollout
        # A = 1
        # B = 1
        # x[t+1] = x_nor[t+1] + A * (x[t] - x_nor[t]) + B * du[t]

        # nonlinear rollout: RK4
        x[t+1] = fd_rk4(x[t], u[t])

        # nonlinear rollout: euler
        # x[t+1] = fd_euler(x_nor[t], u[t])
        
    return x, u

# %%
def cost(x, u, x_target, Q, R):
    J = 0
    for t in range(T+1):
        J += 0.5 * (x[t] - x_target) @ Q @ (x[t] - x_target) + 0.5 * u[t] * R * u[t]
    print("difference of x is ", x[t] - x_target)
    return J

# %%
x = np.array([1,3])
H = np.array([[1,3],[1,3]])

x.T @ H @ x
# Out:
# 40

# %%
Q = jnp.array( [[1,2],[1,2]]  )
x_t = jnp.array( [1,2] )

x = random.normal(key, (2,))
u = random.normal(key, ())

print(x)
print(u)

print("f wrt x is ",fd_rk4_x(x,u))
print("f wrt u is ",fd_rk4_u(x,u))

A_t = fd_rk4_x(x,u)

A_t.T @ Q 

# State deviation weight
# R = 1  # Control effort weight
# Out:
# [0.49798056 0.09021932]
# 1.003158
# f wrt x is  [[1.0023414  0.0100078 ]
#  [0.46833697 1.0023401 ]]
# f wrt u is  [0.00250097 0.50038964]
# Array([[1.4706783, 2.9413567],
#        [1.0123479, 2.0246959]], dtype=float32)

# %%
def backward_pass(x, u, x_target, Q, R):
    # Vx = jnp.zeros(T+1)
    # Vxx = jnp.zeros(T+1)
    # k = jnp.zeros(T)
    # K = jnp.zeros(T)
    

    Vx = np.zeros((T+1,nx))
    Vxx = np.zeros((T+1,nx,nx))
    k = np.zeros(T)
    K = np.zeros((T,nx))

    # Final cost-to-go
    Vx[T] = Q @ ( x[T] - x_target )
    # print("Vx[T] is ", Vx[T])
    Vxx[T] = Q

    # print("In Backward Pass")
    # print("x is", x)
    # print("u is", u)
    
    for t in reversed(range(T)):
        A = fd_rk4_x(x[t], u[t])
        # print("A is ", A)
        B = fd_rk4_u(x[t], u[t])
        # print("B is ", B)
        
        Qx = Q @ ( x[t] - x_target )  + A.T @ Vx[t+1]
        # print("Qx is ", Qx)
        Qu = R * u[t] + B.T @ Vx[t+1]
        # print("Qu is ", Qu)
        
        Qxx = Q + A.T @ Vxx[t+1] @ A
        # print("Qxx is ", Qxx)
        Qux = B.T @ Vxx[t+1] @ A
        # print("Qux is ", Qux)
        Quu = R + B @ Vxx[t+1] @ B
        # print("Quu is ", Quu)
        
        # k[t] = - jnp.linalg.inv(Quu) @ Qu 
        # K[t] = - jnp.linalg.inv(Quu) @ Qux

        k[t] = - Qu / Quu
        K[t] = - Qux / Quu
        
        # Vxx[t] = Qxx + Qux / Quu * Qux
        # Vx[t] = Qx - Qux / Quu * Qu

        Vxx[t] = Qxx + Qux * K[t]
        Vx[t] = Qx + Qux * k[t]
        
    return k, K

# %%
# a = jnp.array([[2,3],[1,3]])
# jnp.linalg.inv(a)

# %%
# Initialization

nx = 2
T = 20  # Number of time steps
x0 = jnp.array([jnp.pi/2+0.01,0])   # Initial position
x_target = jnp.array([jnp.pi/2,0])  # Target position

Q = jnp.diag( jnp.array([10000,500]) )  # State deviation weight
R = 1  # Control effort weight

x = jnp.zeros((T+1,nx))
u = jnp.zeros(T)
J_list = jnp.zeros(0)

J = cost(x, u, x_target, Q, R)
J_list = jnp.append(J_list, J)
J_prev = 0

tol = 1e-5
iter = 0
maxiter = 3e4

# Main iLQR loop

while (abs(J - J_prev) >  tol) and ( iter <  maxiter ) :  # Number of iterations    

    J_prev = J
    
    k, K = backward_pass(x, u, x_target, Q, R)
    
    x, u = forward_pass(x, x0, u)

    J = cost(x, u, x_target, Q, R)
    J_list = jnp.append(J_list, J)

    iter += 1

# Print final trajectories
print("Final state trajectory:", x)
print("Final control inputs:", u)
print("Cost evoluation:", J_list)
# Out:
# difference of x is  [-1.5707964  0.       ]
# difference of x is  [0.23762846 0.20945859]
# difference of x is  [ 0.13566577 -0.01377448]
# difference of x is  [ 0.13989818 -0.01311538]
# difference of x is  [ 0.1413368  -0.01325086]
# difference of x is  [ 0.1401366  -0.01313977]
# difference of x is  [ 0.14098513 -0.01321805]
# difference of x is  [ 0.14033198 -0.01315764]
# difference of x is  [ 0.14078343 -0.01319941]
# difference of x is  [ 0.14042294 -0.01316604]
# difference of x is  [ 0.14065945 -0.01318785]
# difference of x is  [ 0.14045668 -0.01316909]
# difference of x is  [ 0.1405778  -0.01318022]
# difference of x is  [ 0.14045882 -0.01316926]
# difference of x is  [ 0.14051783 -0.01317467]
# difference of x is  [ 0.14044464 -0.01316784]
# difference of x is  [ 0.14046824 -0.01317003]
# difference of x is  [ 0.14042151 -0.01316572]
# difference of x is  [ 0.1404258  -0.01316608]
# difference of x is  [ 0.14039147 -0.01316285]
# difference of x is  [ 0.14038658 -0.01316239]
# difference of x is  [ 0.14035964 -0.01315991]
# difference of x is  [ 0.14034879 -0.01315886]
# difference of x is  [ 0.14032495 -0.01315654]
# difference of x is  [ 0.14031124 -0.01315534]
# difference of x is  [ 0.14028978 -0.01315335]
# difference of x is  [ 0.14027345 -0.01315179]
# difference of x is  [ 0.14025319 -0.01314991]
# difference of x is  [ 0.14023542 -0.0131482 ]
# difference of x is  [ 0.14021635 -0.01314641]
# difference of x is  [ 0.14019716 -0.01314464]
# difference of x is  [ 0.14017844 -0.01314289]
# difference of x is  [ 0.1401583  -0.01314096]
# difference of x is  [ 0.14013982 -0.01313926]
# difference of x is  [ 0.14011991 -0.01313742]
# difference of x is  [ 0.14010024 -0.01313552]
# difference of x is  [ 0.14008021 -0.01313362]
# difference of x is  [ 0.14005971 -0.01313176]
# difference of x is  [ 0.14004028 -0.01312995]
# difference of x is  [ 0.14001942 -0.01312796]
# difference of x is  [ 0.13999951 -0.01312607]
# difference of x is  [ 0.13997793 -0.01312407]
# difference of x is  [ 0.1399585  -0.01312223]
# difference of x is  [ 0.13993657 -0.01312021]
# difference of x is  [ 0.13991666 -0.01311828]
# difference of x is  [ 0.13989401 -0.01311622]
# difference of x is  [ 0.13987386 -0.01311433]
# difference of x is  [ 0.1398511 -0.0131121]
# difference of x is  [ 0.13983023 -0.01311023]
# difference of x is  [ 0.13980842 -0.01310819]
# difference of x is  [ 0.13978624 -0.0131061 ]
# difference of x is  [ 0.13976419 -0.013104  ]
# difference of x is  [ 0.13974166 -0.01310193]
# difference of x is  [ 0.13971984 -0.01309981]
# difference of x is  [ 0.1396966 -0.0130977]
# difference of x is  [ 0.13967395 -0.01309552]
# difference of x is  [ 0.13965118 -0.01309343]
# difference of x is  [ 0.13962829 -0.0130913 ]
# difference of x is  [ 0.13960445 -0.01308897]
# difference of x is  [ 0.13958108 -0.01308684]
# difference of x is  [ 0.13955808 -0.01308472]
# difference of x is  [ 0.13953352 -0.01308238]
# difference of x is  [ 0.1395104  -0.01308019]
# difference of x is  [ 0.1394856  -0.01307787]
# difference of x is  [ 0.13946176 -0.01307566]
# difference of x is  [ 0.13943708 -0.01307332]
# difference of x is  [ 0.139413   -0.01307108]
# difference of x is  [ 0.1393882  -0.01306878]
# difference of x is  [ 0.1393627  -0.01306629]
# difference of x is  [ 0.13933802 -0.01306406]
# difference of x is  [ 0.1393125  -0.01306167]
# difference of x is  [ 0.13928747 -0.01305926]
# difference of x is  [ 0.13926125 -0.01305686]
# difference of x is  [ 0.13923585 -0.01305442]
# difference of x is  [ 0.13920987 -0.013052  ]
# difference of x is  [ 0.13918376 -0.0130496 ]
# difference of x is  [ 0.1391573  -0.01304711]
# difference of x is  [ 0.13913071 -0.01304458]
# difference of x is  [ 0.13910413 -0.01304207]
# difference of x is  [ 0.1390773  -0.01303961]
# difference of x is  [ 0.13905036 -0.01303703]
# difference of x is  [ 0.13902354 -0.01303457]
# difference of x is  [ 0.13899529 -0.01303186]
# difference of x is  [ 0.1389687  -0.01302939]
# difference of x is  [ 0.13893986 -0.0130267 ]
# difference of x is  [ 0.13891256 -0.01302416]
# difference of x is  [ 0.13888443 -0.01302142]
# difference of x is  [ 0.13885593 -0.01301885]
# difference of x is  [ 0.13882768 -0.0130162 ]
# difference of x is  [ 0.13879871 -0.01301342]
# difference of x is  [ 0.13876975 -0.01301076]
# difference of x is  [ 0.1387409  -0.01300799]
# difference of x is  [ 0.13871145 -0.01300526]
# difference of x is  [ 0.13868177 -0.01300249]
# difference of x is  [ 0.13865316 -0.01299978]
# difference of x is  [ 0.13862193 -0.01299684]
# difference of x is  [ 0.13859332 -0.01299421]
# difference of x is  [ 0.13856196 -0.01299121]
# difference of x is  [ 0.13853276 -0.01298855]
# difference of x is  [ 0.13850081 -0.01298548]
# difference of x is  [ 0.13847065 -0.01298268]
# difference of x is  [ 0.13843966 -0.01297977]
# difference of x is  [ 0.13840842 -0.01297685]
# difference of x is  [ 0.13837767 -0.01297392]
# difference of x is  [ 0.13834488 -0.01297092]
# difference of x is  [ 0.13831449 -0.01296799]
# difference of x is  [ 0.13828158 -0.01296498]
# difference of x is  [ 0.13824964 -0.01296188]
# difference of x is  [ 0.13821757 -0.01295894]
# difference of x is  [ 0.13818443 -0.01295586]
# difference of x is  [ 0.13815188 -0.01295271]
# difference of x is  [ 0.13811934 -0.01294975]
# difference of x is  [ 0.13808525 -0.0129465 ]
# difference of x is  [ 0.13805318 -0.01294355]
# difference of x is  [ 0.13801837 -0.01294019]
# difference of x is  [ 0.13798559 -0.01293722]
# difference of x is  [ 0.13795078 -0.01293392]
# difference of x is  [ 0.1379174  -0.01293075]
# difference of x is  [ 0.13788176 -0.01292743]
# difference of x is  [ 0.13784838 -0.01292429]
# difference of x is  [ 0.13781261 -0.01292098]
# difference of x is  [ 0.13777876 -0.0129177 ]
# difference of x is  [ 0.13774216 -0.01291439]
# difference of x is  [ 0.13770795 -0.01291114]
# difference of x is  [ 0.13767076 -0.01290762]
# difference of x is  [ 0.13763666 -0.01290444]
# difference of x is  [ 0.13759935 -0.01290092]
# difference of x is  [ 0.1375637  -0.01289765]
# difference of x is  [ 0.13752687 -0.01289407]
# difference of x is  [ 0.13748991 -0.01289072]
# difference of x is  [ 0.13745368 -0.01288728]
# difference of x is  [ 0.13741589 -0.01288371]
# difference of x is  [ 0.13737917 -0.0128803 ]
# difference of x is  [ 0.13734126 -0.01287676]
# difference of x is  [ 0.13730335 -0.01287312]
# difference of x is  [ 0.13726556 -0.01286967]
# difference of x is  [ 0.13722765 -0.0128661 ]
# difference of x is  [ 0.13718855 -0.01286241]
# difference of x is  [ 0.13715029 -0.01285881]
# difference of x is  [ 0.13711119 -0.01285514]
# difference of x is  [ 0.13707244 -0.01285156]
# difference of x is  [ 0.13703299 -0.01284776]
# difference of x is  [ 0.13699305 -0.0128441 ]
# difference of x is  [ 0.13695395 -0.0128404 ]
# difference of x is  [ 0.13691354 -0.0128366 ]
# difference of x is  [ 0.13687372 -0.01283287]
# difference of x is  [ 0.13683307 -0.0128291 ]
# difference of x is  [ 0.1367923  -0.01282518]
# difference of x is  [ 0.13675153 -0.01282144]
# difference of x is  [ 0.13671088 -0.01281761]
# difference of x is  [ 0.13666904 -0.01281366]
# difference of x is  [ 0.13662791 -0.0128098 ]
# difference of x is  [ 0.13658631 -0.01280592]
# difference of x is  [ 0.13654351 -0.01280189]
# difference of x is  [ 0.13650227 -0.01279801]
# difference of x is  [ 0.13645875 -0.01279399]
# difference of x is  [ 0.13641691 -0.01279   ]
# difference of x is  [ 0.13637388 -0.01278602]
# difference of x is  [ 0.13633084 -0.01278191]
# difference of x is  [ 0.13628733 -0.01277792]
# difference of x is  [ 0.13624454 -0.01277383]
# difference of x is  [ 0.13619947 -0.01276962]
# difference of x is  [ 0.13615644 -0.0127656 ]
# difference of x is  [ 0.1361115  -0.01276141]
# difference of x is  [ 0.13606787 -0.01275722]
# difference of x is  [ 0.13602257 -0.01275302]
# difference of x is  [ 0.13597786 -0.01274888]
# difference of x is  [ 0.13593304 -0.01274462]
# difference of x is  [ 0.13588727 -0.01274037]
# difference of x is  [ 0.13584173 -0.01273602]
# difference of x is  [ 0.1357956  -0.01273177]
# difference of x is  [ 0.13574982 -0.01272746]
# difference of x is  [ 0.13570368 -0.01272308]
# difference of x is  [ 0.13565707 -0.01271878]
# difference of x is  [ 0.13561034 -0.01271438]
# difference of x is  [ 0.1355629  -0.01270992]
# difference of x is  [ 0.13551676 -0.01270558]
# difference of x is  [ 0.13546848 -0.01270102]
# difference of x is  [ 0.13542128 -0.01269668]
# difference of x is  [ 0.135373   -0.01269209]
# difference of x is  [ 0.1353252  -0.01268764]
# difference of x is  [ 0.13527644 -0.01268304]
# difference of x is  [ 0.13522792 -0.01267845]
# difference of x is  [ 0.13518    -0.01267404]
# difference of x is  [ 0.1351291  -0.01266921]
# difference of x is  [ 0.13508117 -0.01266475]
# difference of x is  [ 0.13503087 -0.01265999]
# difference of x is  [ 0.13498211 -0.0126554 ]
# difference of x is  [ 0.13493156 -0.01265073]
# difference of x is  [ 0.1348815 -0.012646 ]
# difference of x is  [ 0.1348306  -0.01264121]
# difference of x is  [ 0.13478136 -0.01263663]
# difference of x is  [ 0.13472855 -0.01263162]
# difference of x is  [ 0.13467908 -0.01262704]
# difference of x is  [ 0.13462603 -0.012622  ]
# difference of x is  [ 0.1345762  -0.01261736]
# difference of x is  [ 0.13452256 -0.01261237]
# difference of x is  [ 0.1344719  -0.01260756]
# difference of x is  [ 0.13441932 -0.01260265]
# difference of x is  [ 0.13436615 -0.01259766]
# difference of x is  [ 0.13431454 -0.01259282]
# difference of x is  [ 0.13426054 -0.01258773]
# difference of x is  [ 0.13420796 -0.01258286]
# difference of x is  [ 0.13415432 -0.0125778 ]
# difference of x is  [ 0.1341002  -0.01257268]
# difference of x is  [ 0.13404751 -0.01256783]
# difference of x is  [ 0.13399136 -0.01256246]
# difference of x is  [ 0.13393927 -0.01255763]
# difference of x is  [ 0.13388228 -0.01255228]
# difference of x is  [ 0.1338296  -0.01254734]
# difference of x is  [ 0.13377309 -0.01254199]
# difference of x is  [ 0.13371825 -0.0125369 ]
# difference of x is  [ 0.13366294 -0.01253174]
# difference of x is  [ 0.13360667 -0.01252639]
# difference of x is  [ 0.13355076 -0.01252118]
# difference of x is  [ 0.13349485 -0.01251593]
# difference of x is  [ 0.13343775 -0.01251059]
# difference of x is  [ 0.13338208 -0.01250532]
# difference of x is  [ 0.13332391 -0.01249991]
# difference of x is  [ 0.13326812 -0.01249467]
# difference of x is  [ 0.13321006 -0.01248922]
# difference of x is  [ 0.13315237 -0.01248378]
# difference of x is  [ 0.13309503 -0.01247847]
# difference of x is  [ 0.1330359  -0.01247286]
# difference of x is  [ 0.13297904 -0.01246754]
# difference of x is  [ 0.13291931 -0.01246191]
# difference of x is  [ 0.1328609  -0.01245652]
# difference of x is  [ 0.13280249 -0.01245096]
# difference of x is  [ 0.1327424  -0.01244536]
# difference of x is  [ 0.13268411 -0.01243985]
# difference of x is  [ 0.13262355 -0.01243426]
# difference of x is  [ 0.1325643  -0.01242861]
# difference of x is  [ 0.13250375 -0.01242298]
# difference of x is  [ 0.13244355 -0.01241734]
# difference of x is  [ 0.13238311 -0.01241166]
# difference of x is  [ 0.13232172 -0.01240587]
# difference of x is  [ 0.13226175 -0.01240027]
# difference of x is  [ 0.13219869 -0.01239433]
# difference of x is  [ 0.13213956 -0.01238886]
# difference of x is  [ 0.13207638 -0.01238285]
# difference of x is  [ 0.13201547 -0.01237717]
# difference of x is  [ 0.1319524  -0.01237124]
# difference of x is  [ 0.13189101 -0.01236551]
# difference of x is  [ 0.13182688 -0.01235949]
# difference of x is  [ 0.13176572 -0.01235375]
# difference of x is  [ 0.13170147 -0.01234768]
# difference of x is  [ 0.13163936 -0.0123419 ]
# difference of x is  [ 0.13157451 -0.01233578]
# difference of x is  [ 0.13151276 -0.01233006]
# difference of x is  [ 0.13144696 -0.01232382]
# difference of x is  [ 0.13138461 -0.012318  ]
# difference of x is  [ 0.13131833 -0.01231174]
# difference of x is  [ 0.13125575 -0.0123059 ]
# difference of x is  [ 0.1311884 -0.0122996]
# difference of x is  [ 0.1311264  -0.01229378]
# difference of x is  [ 0.13105845 -0.01228738]
# difference of x is  [ 0.13099587 -0.01228154]
# difference of x is  [ 0.13092732 -0.01227507]
# difference of x is  [ 0.13086402 -0.01226917]
# difference of x is  [ 0.13079536 -0.01226274]
# difference of x is  [ 0.1307323  -0.01225678]
# difference of x is  [ 0.13066328 -0.01225035]
# difference of x is  [ 0.13059807 -0.01224419]
# difference of x is  [ 0.13052964 -0.0122378 ]
# difference of x is  [ 0.13046479 -0.01223172]
# difference of x is  [ 0.13039434 -0.01222513]
# difference of x is  [ 0.13033032 -0.01221908]
# difference of x is  [ 0.13025904 -0.01221243]
# difference of x is  [ 0.13019443 -0.01220633]
# difference of x is  [ 0.13012266 -0.0121996 ]
# difference of x is  [ 0.13005841 -0.01219361]
# difference of x is  [ 0.12998545 -0.01218678]
# difference of x is  [ 0.12992191 -0.01218079]
# difference of x is  [ 0.12984705 -0.01217376]
# difference of x is  [ 0.12978363 -0.01216782]
# difference of x is  [ 0.12970817 -0.01216074]
# difference of x is  [ 0.12964475 -0.01215476]
# difference of x is  [ 0.12956977 -0.01214779]
# difference of x is  [ 0.12950456 -0.01214162]
# difference of x is  [ 0.12942898 -0.01213462]
# difference of x is  [ 0.12936401 -0.01212844]
# difference of x is  [ 0.12928772 -0.01212133]
# difference of x is  [ 0.12922323 -0.01211523]
# difference of x is  [ 0.12914503 -0.01210792]
# difference of x is  [ 0.12908125 -0.01210195]
# difference of x is  [ 0.1290021 -0.0120945]
# difference of x is  [ 0.12893915 -0.01208862]
# difference of x is  [ 0.12885809 -0.01208099]
# difference of x is  [ 0.12879539 -0.01207514]
# difference of x is  [ 0.12871397 -0.01206753]
# difference of x is  [ 0.12865055 -0.01206148]
# difference of x is  [ 0.12856865 -0.01205391]
# difference of x is  [ 0.12850595 -0.01204794]
# difference of x is  [ 0.12842178 -0.01204009]
# difference of x is  [ 0.12836099 -0.01203439]
# difference of x is  [ 0.1282742  -0.01202622]
# difference of x is  [ 0.12821484 -0.01202068]
# difference of x is  [ 0.12812626 -0.01201236]
# difference of x is  [ 0.12806761 -0.01200685]
# difference of x is  [ 0.12797749 -0.01199845]
# difference of x is  [ 0.12792027 -0.01199304]
# difference of x is  [ 0.12782764 -0.01198437]
# difference of x is  [ 0.12777233 -0.01197916]
# difference of x is  [ 0.12767625 -0.01197015]
# difference of x is  [ 0.1276238  -0.01196524]
# difference of x is  [ 0.12752414 -0.01195589]
# difference of x is  [ 0.12747502 -0.01195128]
# difference of x is  [ 0.12737119 -0.01194156]
# difference of x is  [ 0.12732553 -0.01193721]
# difference of x is  [ 0.1272173  -0.01192717]
# difference of x is  [ 0.12717569 -0.01192315]
# difference of x is  [ 0.12706208 -0.01191258]
# difference of x is  [ 0.1270256 -0.0119091]
# difference of x is  [ 0.12690592 -0.01189795]
# difference of x is  [ 0.12687612 -0.01189506]
# difference of x is  [ 0.12674665 -0.01188301]
# difference of x is  [ 0.12672794 -0.01188113]
# difference of x is  [ 0.12658525 -0.0118679 ]
# difference of x is  [ 0.12658048 -0.01186731]
# difference of x is  [ 0.12642145 -0.01185253]
# difference of x is  [ 0.12643385 -0.0118536 ]
# difference of x is  [ 0.12625551 -0.01183694]
# difference of x is  [ 0.12628818 -0.01183991]
# difference of x is  [ 0.12608707 -0.01182113]
# difference of x is  [ 0.12614465 -0.01182644]
# difference of x is  [ 0.12591362 -0.01180494]
# difference of x is  [ 0.12600553 -0.01181333]
# difference of x is  [ 0.12573397 -0.01178814]
# difference of x is  [ 0.12587225 -0.01180078]
# difference of x is  [ 0.12554681 -0.01177056]
# difference of x is  [ 0.12574518 -0.01178889]
# difference of x is  [ 0.12535095 -0.01175226]
# difference of x is  [ 0.125628   -0.01177785]
# difference of x is  [ 0.12514102 -0.01173261]
# difference of x is  [ 0.12552571 -0.01176818]
# difference of x is  [ 0.12491441 -0.01171141]
# difference of x is  [ 0.12544191 -0.01176031]
# difference of x is  [ 0.12466359 -0.01168803]
# difference of x is  [ 0.1253854  -0.01175481]
# difference of x is  [ 0.12438083 -0.01166169]
# difference of x is  [ 0.1253674  -0.01175302]
# difference of x is  [ 0.12405229 -0.01163106]
# difference of x is  [ 0.12540364 -0.01175623]
# difference of x is  [ 0.1236608  -0.01159474]
# difference of x is  [ 0.12551689 -0.01176667]
# difference of x is  [ 0.12318194 -0.0115503 ]
# difference of x is  [ 0.12574089 -0.01178746]
# difference of x is  [ 0.12258101 -0.01149466]
# difference of x is  [ 0.12612343 -0.01182316]
# difference of x is  [ 0.12180912 -0.01142348]
# difference of x is  [ 0.12673664 -0.01188054]
# difference of x is  [ 0.12080145 -0.01133091]
# difference of x is  [ 0.12768316 -0.01196958]
# difference of x is  [ 0.11947858 -0.01121014]
# difference of x is  [ 0.12910342 -0.01210383]
# difference of x is  [ 0.11775553 -0.01105415]
# difference of x is  [ 0.13117397 -0.01230103]
# difference of x is  [ 0.11558425 -0.01086001]
# difference of x is  [ 0.13404477 -0.01257687]
# difference of x is  [ 0.11305428 -0.01063827]
# difference of x is  [ 0.13766217 -0.01292819]
# difference of x is  [ 0.1104908  -0.01042039]
# difference of x is  [ 0.14150167 -0.0133054 ]
# difference of x is  [ 0.10841668 -0.0102526 ]
# difference of x is  [ 0.14457238 -0.01361063]
# difference of x is  [ 0.10714817 -0.01015661]
# difference of x is  [ 0.1462791  -0.01378188]
# difference of x is  [ 0.10654211 -0.01011337]
# difference of x is  [ 0.14694393 -0.01384931]
# difference of x is  [ 0.10625517 -0.01009219]
# difference of x is  [ 0.14718533 -0.01387404]
# difference of x is  [ 0.10607886 -0.01007819]
# difference of x is  [ 0.14729643 -0.01388568]
# difference of x is  [ 0.10593665 -0.01006635]
# difference of x is  [ 0.1473651  -0.01389292]
# difference of x is  [ 0.10579944 -0.01005474]
# difference of x is  [ 0.14743662 -0.01390042]
# difference of x is  [ 0.10566664 -0.01004355]
# difference of x is  [ 0.14749992 -0.01390712]
# difference of x is  [ 0.10553718 -0.01003258]
# difference of x is  [ 0.1475581  -0.01391338]
# difference of x is  [ 0.10540736 -0.0100215 ]
# difference of x is  [ 0.14761996 -0.01391995]
# difference of x is  [ 0.105281  -0.0100108]
# difference of x is  [ 0.14767241 -0.01392558]
# difference of x is  [ 0.10515356 -0.00999995]
# difference of x is  [ 0.14773369 -0.01393206]
# difference of x is  [ 0.10502768 -0.00998928]
# difference of x is  [ 0.14778936 -0.01393804]
# difference of x is  [ 0.10490167 -0.00997858]
# difference of x is  [ 0.14785147 -0.01394465]
# difference of x is  [ 0.10477495 -0.00996786]
# difference of x is  [ 0.14791048 -0.01395093]
# difference of x is  [ 0.10465539 -0.00995777]
# difference of x is  [ 0.14795792 -0.01395606]
# difference of x is  [ 0.10453379 -0.00994739]
# difference of x is  [ 0.14801443 -0.01396207]
# difference of x is  [ 0.10441053 -0.00993701]
# difference of x is  [ 0.14807224 -0.01396826]
# difference of x is  [ 0.10429215 -0.00992698]
# difference of x is  [ 0.14812028 -0.01397349]
# difference of x is  [ 0.10417521 -0.00991698]
# difference of x is  [ 0.14817071 -0.01397892]
# difference of x is  [ 0.10405374 -0.00990668]
# difference of x is  [ 0.148229   -0.01398512]
# difference of x is  [ 0.10393524 -0.00989672]
# difference of x is  [ 0.14828312 -0.01399091]
# difference of x is  [ 0.10382128 -0.00988708]
# difference of x is  [ 0.14832687 -0.01399566]
# difference of x is  [ 0.10370278 -0.009877  ]
# difference of x is  [ 0.1483854  -0.01400193]
# difference of x is  [ 0.10359025 -0.00986755]
# difference of x is  [ 0.14842749 -0.01400652]
# difference of x is  [ 0.10347807 -0.00985798]
# difference of x is  [ 0.14847493 -0.01401165]
# difference of x is  [ 0.10336423 -0.00984834]
# difference of x is  [ 0.14852512 -0.01401709]
# difference of x is  [ 0.10325456 -0.00983908]
# difference of x is  [ 0.14856839 -0.01402178]
# difference of x is  [ 0.10314095 -0.0098294 ]
# difference of x is  [ 0.14861965 -0.01402729]
# difference of x is  [ 0.10302889 -0.00982001]
# difference of x is  [ 0.14866853 -0.01403253]
# difference of x is  [ 0.10291803 -0.00981068]
# difference of x is  [ 0.14871466 -0.01403754]
# difference of x is  [ 0.10281134 -0.00980159]
# difference of x is  [ 0.1487577  -0.01404224]
# difference of x is  [ 0.10270333 -0.00979249]
# difference of x is  [ 0.14880192 -0.01404701]
# difference of x is  [ 0.10259295 -0.00978315]
# difference of x is  [ 0.14885306 -0.01405252]
# difference of x is  [ 0.10248613 -0.00977416]
# difference of x is  [ 0.14889586 -0.0140572 ]
# difference of x is  [ 0.10237813 -0.00976503]
# difference of x is  [ 0.14894259 -0.01406223]
# difference of x is  [ 0.10227764 -0.00975659]
# difference of x is  [ 0.14897454 -0.01406583]
# difference of x is  [ 0.10216856 -0.00974727]
# difference of x is  [ 0.1490264  -0.01407147]
# difference of x is  [ 0.10206795 -0.00973885]
# difference of x is  [ 0.14906049 -0.01407519]
# difference of x is  [ 0.10196316 -0.00972991]
# difference of x is  [ 0.14910495 -0.01408002]
# difference of x is  [ 0.10186005 -0.00972126]
# difference of x is  [ 0.14914846 -0.01408476]
# difference of x is  [ 0.10175693 -0.00971255]
# difference of x is  [ 0.14918756 -0.01408906]
# difference of x is  [ 0.10165679 -0.00970407]
# difference of x is  [ 0.14922595 -0.01409328]
# difference of x is  [ 0.10155559 -0.00969556]
# difference of x is  [ 0.1492678  -0.01409781]
# difference of x is  [ 0.10145628 -0.00968721]
# difference of x is  [ 0.14930141 -0.01410152]
# difference of x is  [ 0.10135639 -0.00967875]
# difference of x is  [ 0.14934576 -0.01410638]
# difference of x is  [ 0.10125351 -0.00967005]
# difference of x is  [ 0.14938974 -0.01411117]
# difference of x is  [ 0.10115528 -0.00966183]
# difference of x is  [ 0.14942718 -0.01411526]
# difference of x is  [ 0.10105836 -0.00965365]
# difference of x is  [ 0.14946175 -0.0141191 ]
# difference of x is  [ 0.10096002 -0.00964532]
# difference of x is  [ 0.14949965 -0.01412328]
# difference of x is  [ 0.10086334 -0.00963723]
# difference of x is  [ 0.14954007 -0.01412766]
# difference of x is  [ 0.10076487 -0.00962889]
# difference of x is  [ 0.1495781  -0.01413186]
# difference of x is  [ 0.10066748 -0.00962073]
# difference of x is  [ 0.1496172  -0.01413611]
# difference of x is  [ 0.10057259 -0.00961274]
# difference of x is  [ 0.14965391 -0.01414017]
# difference of x is  [ 0.10047805 -0.00960485]
# difference of x is  [ 0.14968848 -0.01414399]
# difference of x is  [ 0.10038435 -0.00959687]
# difference of x is  [ 0.14972281 -0.01414779]
# difference of x is  [ 0.10028923 -0.00958884]
# difference of x is  [ 0.14975953 -0.01415189]
# difference of x is  [ 0.10019541 -0.00958093]
# difference of x is  [ 0.1497953  -0.01415581]
# difference of x is  [ 0.10010123 -0.00957298]
# difference of x is  [ 0.14983475 -0.01416017]
# difference of x is  [ 0.10000968 -0.00956537]
# difference of x is  [ 0.14986336 -0.01416335]
# difference of x is  [ 0.09991837 -0.00955759]
# difference of x is  [ 0.14989746 -0.01416716]
# difference of x is  [ 0.09982753 -0.00954996]
# difference of x is  [ 0.14992785 -0.01417056]
# difference of x is  [ 0.09973669 -0.00954227]
# difference of x is  [ 0.14996493 -0.01417464]
# difference of x is  [ 0.09964359 -0.00953452]
# difference of x is  [ 0.15000033 -0.0141785 ]
# difference of x is  [ 0.09955275 -0.00952688]
# difference of x is  [ 0.15003586 -0.01418247]
# difference of x is  [ 0.09946358 -0.00951939]
# difference of x is  [ 0.15006554 -0.0141858 ]
# difference of x is  [ 0.09937799 -0.00951214]
# difference of x is  [ 0.15009093 -0.01418871]
# difference of x is  [ 0.09928477 -0.00950429]
# difference of x is  [ 0.15013266 -0.01419318]
# difference of x is  [ 0.09919548 -0.00949684]
# difference of x is  [ 0.15016103 -0.01419642]
# difference of x is  [ 0.09910846 -0.00948947]
# difference of x is  [ 0.15019214 -0.01419991]
# difference of x is  [ 0.09901977 -0.00948202]
# difference of x is  [ 0.150226   -0.01420364]
# difference of x is  [ 0.09893358 -0.00947482]
# difference of x is  [ 0.15025508 -0.01420691]
# difference of x is  [ 0.09884453 -0.00946731]
# difference of x is  [ 0.15028799 -0.01421054]
# difference of x is  [ 0.09875751 -0.00946   ]
# difference of x is  [ 0.15032125 -0.01421426]
# difference of x is  [ 0.09867215 -0.00945291]
# difference of x is  [ 0.15034664 -0.0142171 ]
# difference of x is  [ 0.09858644 -0.00944563]
# difference of x is  [ 0.15037775 -0.0142206 ]
# difference of x is  [ 0.09850192 -0.00943855]
# difference of x is  [ 0.15040529 -0.0142237 ]
# difference of x is  [ 0.09841502 -0.0094312 ]
# difference of x is  [ 0.15044141 -0.01422777]
# difference of x is  [ 0.09832931 -0.00942403]
# difference of x is  [ 0.15046966 -0.01423091]
# difference of x is  [ 0.09824526 -0.00941695]
# difference of x is  [ 0.1504978 -0.0142341]
# difference of x is  [ 0.09816134 -0.00940991]
# difference of x is  [ 0.15052712 -0.01423736]
# difference of x is  [ 0.09807742 -0.00940286]
# difference of x is  [ 0.15055573 -0.01424058]
# difference of x is  [ 0.09799576 -0.00939605]
# difference of x is  [ 0.15058124 -0.01424346]
# difference of x is  [ 0.09791005 -0.00938879]
# difference of x is  [ 0.15061438 -0.01424716]
# difference of x is  [ 0.09782565 -0.00938175]
# difference of x is  [ 0.1506449  -0.01425058]
# difference of x is  [ 0.0977447  -0.00937498]
# difference of x is  [ 0.15066922 -0.01425336]
# difference of x is  [ 0.09766304 -0.0093681 ]
# difference of x is  [ 0.15069354 -0.01425613]
# difference of x is  [ 0.09758162 -0.0093612 ]
# difference of x is  [ 0.15072179 -0.01425934]
# difference of x is  [ 0.09749687 -0.00935414]
# difference of x is  [ 0.15075755 -0.01426321]
# difference of x is  [ 0.09741724 -0.00934751]
# difference of x is  [ 0.15077949 -0.0142658 ]
# difference of x is  [ 0.09733558 -0.00934062]
# difference of x is  [ 0.15081   -0.0142692]
# difference of x is  [ 0.09725296 -0.00933375]
# difference of x is  [ 0.15084016 -0.01427257]
# difference of x is  [ 0.09717548 -0.00932723]
# difference of x is  [ 0.15085888 -0.01427483]
# difference of x is  [ 0.09709394 -0.00932031]
# difference of x is  [ 0.1508894  -0.01427823]
# difference of x is  [ 0.09701622 -0.00931383]
# difference of x is  [ 0.15090859 -0.01428049]
# difference of x is  [ 0.09693611 -0.00930707]
# difference of x is  [ 0.1509397  -0.01428393]
# difference of x is  [ 0.09685683 -0.00930043]
# difference of x is  [ 0.150962   -0.01428655]
# difference of x is  [ 0.09677804 -0.00929385]
# difference of x is  [ 0.15099049 -0.01428969]
# difference of x is  [ 0.09669864 -0.00928719]
# difference of x is  [ 0.15101409 -0.01429243]
# difference of x is  [ 0.09661877 -0.00928046]
# difference of x is  [ 0.15104425 -0.01429578]
# difference of x is  [ 0.09654319 -0.00927419]
# difference of x is  [ 0.15106153 -0.01429787]
# difference of x is  [ 0.09646142 -0.00926725]
# difference of x is  [ 0.15109706 -0.01430179]
# difference of x is  [ 0.09638464 -0.00926086]
# difference of x is  [ 0.15111768 -0.01430423]
# difference of x is  [ 0.09630644 -0.00925433]
# difference of x is  [ 0.15114522 -0.01430728]
# difference of x is  [ 0.09622967 -0.0092479 ]
# difference of x is  [ 0.1511656  -0.01430968]
# difference of x is  [ 0.09615231 -0.0092414 ]
# difference of x is  [ 0.15119398 -0.01431285]
# difference of x is  [ 0.09607565 -0.00923501]
# difference of x is  [ 0.15121412 -0.01431521]
# difference of x is  [ 0.09600043 -0.00922868]
# difference of x is  [ 0.15123653 -0.01431778]
# difference of x is  [ 0.09592354 -0.00922223]
# difference of x is  [ 0.1512636  -0.01432083]
# difference of x is  [ 0.0958451  -0.00921568]
# difference of x is  [ 0.15128887 -0.01432371]
# difference of x is  [ 0.09577096 -0.00920948]
# difference of x is  [ 0.15130877 -0.01432608]
# difference of x is  [ 0.09569478 -0.00920304]
# difference of x is  [ 0.1513356  -0.01432914]
# difference of x is  [ 0.09562218 -0.00919697]
# difference of x is  [ 0.15135014 -0.01433092]
# difference of x is  [ 0.09554434 -0.00919033]
# difference of x is  [ 0.15138364 -0.01433464]
# difference of x is  [ 0.09546793 -0.00918408]
# difference of x is  [ 0.1514095  -0.01433753]
# difference of x is  [ 0.09539402 -0.00917792]
# difference of x is  [ 0.15142739 -0.01433968]
# difference of x is  [ 0.09531844 -0.00917153]
# difference of x is  [ 0.15145528 -0.01434279]
# difference of x is  [ 0.09524322 -0.00916533]
# difference of x is  [ 0.15147674 -0.01434525]
# difference of x is  [ 0.09516788 -0.00915897]
# difference of x is  [ 0.15150464 -0.01434843]
# difference of x is  [ 0.09509504 -0.00915292]
# difference of x is  [ 0.15152156 -0.01435047]
# difference of x is  [ 0.09502459 -0.00914697]
# difference of x is  [ 0.15153491 -0.0143521 ]
# difference of x is  [ 0.09494972 -0.00914066]
# difference of x is  [ 0.15156603 -0.01435554]
# difference of x is  [ 0.09487522 -0.00913452]
# difference of x is  [ 0.15158677 -0.01435795]
# difference of x is  [ 0.09480214 -0.00912839]
# difference of x is  [ 0.1516087  -0.01436051]
# difference of x is  [ 0.09472716 -0.00912209]
# difference of x is  [ 0.151636   -0.01436359]
# difference of x is  [ 0.09465885 -0.0091165 ]
# difference of x is  [ 0.15164208 -0.01436449]
# difference of x is  [ 0.09458339 -0.00911001]
# difference of x is  [ 0.15167391 -0.01436801]
# difference of x is  [ 0.09451175 -0.00910412]
# difference of x is  [ 0.15169239 -0.01437022]
# difference of x is  [ 0.09444046 -0.00909813]
# difference of x is  [ 0.15171373 -0.01437269]
# difference of x is  [ 0.09436584 -0.00909185]
# difference of x is  [ 0.15173829 -0.01437552]
# difference of x is  [ 0.09429336 -0.00908586]
# difference of x is  [ 0.15176046 -0.01437803]
# difference of x is  [ 0.09422147 -0.00907981]
# difference of x is  [ 0.15178096 -0.01438046]
# difference of x is  [ 0.09414923 -0.00907379]
# difference of x is  [ 0.1518029  -0.01438299]
# difference of x is  [ 0.09407651 -0.00906774]
# difference of x is  [ 0.15182352 -0.01438535]
# difference of x is  [ 0.09400702 -0.0090619 ]
# difference of x is  [ 0.15184283 -0.01438764]
# difference of x is  [ 0.09393835 -0.00905618]
# difference of x is  [ 0.1518557  -0.01438922]
# difference of x is  [ 0.09386504 -0.00904994]
# difference of x is  [ 0.15188253 -0.01439231]
# difference of x is  [ 0.09379244 -0.00904389]
# difference of x is  [ 0.15190554 -0.01439497]
# difference of x is  [ 0.0937196  -0.00903781]
# difference of x is  [ 0.15193117 -0.01439789]
# difference of x is  [ 0.09365344 -0.00903237]
# difference of x is  [ 0.15193987 -0.01439907]
# difference of x is  [ 0.09358287 -0.00902639]
# difference of x is  [ 0.15196276 -0.01440165]
# difference of x is  [ 0.09351373 -0.00902061]
# difference of x is  [ 0.15197659 -0.01440341]
# difference of x is  [ 0.09344053 -0.00901442]
# difference of x is  [ 0.15200794 -0.01440689]
# difference of x is  [ 0.09337115 -0.00900874]
# difference of x is  [ 0.15202165 -0.01440859]
# difference of x is  [ 0.09329927 -0.00900267]
# difference of x is  [ 0.15204775 -0.01441156]
# difference of x is  [ 0.09323323 -0.00899725]
# difference of x is  [ 0.15205431 -0.01441251]
# difference of x is  [ 0.0931592  -0.00899092]
# difference of x is  [ 0.15208972 -0.01441639]
# difference of x is  [ 0.0930903  -0.00898533]
# difference of x is  [ 0.15210307 -0.01441807]
# difference of x is  [ 0.0930208  -0.00897947]
# difference of x is  [ 0.15212214 -0.01442032]
# difference of x is  [ 0.09295225 -0.00897372]
# difference of x is  [ 0.1521405  -0.01442247]
# difference of x is  [ 0.09288514 -0.00896815]
# difference of x is  [ 0.15215147 -0.0144239 ]
# difference of x is  [ 0.09281552 -0.00896227]
# difference of x is  [ 0.1521771  -0.01442678]
# difference of x is  [ 0.0927465  -0.00895657]
# difference of x is  [ 0.15219212 -0.01442861]
# difference of x is  [ 0.09267616 -0.00895065]
# difference of x is  [ 0.15221763 -0.0144315 ]
# difference of x is  [ 0.09260774 -0.00894501]
# difference of x is  [ 0.15223205 -0.01443328]
# difference of x is  [ 0.09253871 -0.00893919]
# difference of x is  [ 0.15225172 -0.01443558]
# difference of x is  [ 0.09247327 -0.00893374]
# difference of x is  [ 0.15226305 -0.01443705]
# difference of x is  [ 0.09240532 -0.00892802]
# difference of x is  [ 0.15228081 -0.01443914]
# difference of x is  [ 0.0923351  -0.00892213]
# difference of x is  [ 0.1523062  -0.01444204]
# difference of x is  [ 0.09226596 -0.00891642]
# difference of x is  [ 0.15232265 -0.01444402]
# difference of x is  [ 0.09220076 -0.00891096]
# difference of x is  [ 0.15233505 -0.01444559]
# difference of x is  [ 0.09213448 -0.00890537]
# difference of x is  [ 0.15235138 -0.01444758]
# difference of x is  [ 0.09206259 -0.00889933]
# difference of x is  [ 0.1523782 -0.0144506]
# difference of x is  [ 0.09199381 -0.0088937 ]
# difference of x is  [ 0.15239692 -0.01445278]
# difference of x is  [ 0.09192467 -0.00888794]
# difference of x is  [ 0.15241647 -0.01445507]
# difference of x is  [ 0.09186029 -0.00888258]
# difference of x is  [ 0.15242636 -0.0144564 ]
# difference of x is  [ 0.09179068 -0.00887667]
# difference of x is  [ 0.15245175 -0.01445929]
# difference of x is  [ 0.09172022 -0.00887087]
# difference of x is  [ 0.15247226 -0.01446169]
# difference of x is  [ 0.0916568  -0.00886563]
# difference of x is  [ 0.15247846 -0.01446257]
# difference of x is  [ 0.09158921 -0.00885994]
# difference of x is  [ 0.15250051 -0.01446506]
# difference of x is  [ 0.09152293 -0.00885443]
# difference of x is  [ 0.15251505 -0.0144669 ]
# difference of x is  [ 0.09145141 -0.0088484 ]
# difference of x is  [ 0.15254223 -0.01446997]
# difference of x is  [ 0.09138596 -0.00884305]
# difference of x is  [ 0.15255535 -0.01447162]
# difference of x is  [ 0.09132051 -0.00883755]
# difference of x is  [ 0.15256667 -0.01447306]
# difference of x is  [ 0.09125197 -0.00883182]
# difference of x is  [ 0.15259016 -0.0144757 ]
# difference of x is  [ 0.09118605 -0.00882635]
# difference of x is  [ 0.15260339 -0.01447741]
# difference of x is  [ 0.09112132 -0.0088209 ]
# difference of x is  [ 0.15261674 -0.01447907]
# difference of x is  [ 0.09105527 -0.00881537]
# difference of x is  [ 0.15263307 -0.01448104]
# difference of x is  [ 0.09098732 -0.00880968]
# difference of x is  [ 0.15265214 -0.01448331]
# difference of x is  [ 0.09092426 -0.00880451]
# difference of x is  [ 0.15265751 -0.01448409]
# difference of x is  [ 0.09085476 -0.00879855]
# difference of x is  [ 0.15268672 -0.01448741]
# difference of x is  [ 0.0907892  -0.00879323]
# difference of x is  [ 0.15269661 -0.0144887 ]
# difference of x is  [ 0.09072053 -0.00878738]
# difference of x is  [ 0.15272033 -0.01449145]
# difference of x is  [ 0.09065533 -0.00878201]
# difference of x is  [ 0.1527301  -0.01449277]
# difference of x is  [ 0.09058726 -0.00877633]
# difference of x is  [ 0.15275156 -0.01449524]
# difference of x is  [ 0.09052134 -0.00877079]
# difference of x is  [ 0.15276814 -0.01449727]
# difference of x is  [ 0.09045243 -0.00876508]
# difference of x is  [ 0.15279186 -0.01449997]
# difference of x is  [ 0.09038794 -0.00875972]
# difference of x is  [ 0.15280032 -0.01450115]
# difference of x is  [ 0.090325   -0.00875448]
# difference of x is  [ 0.15280902 -0.01450231]
# difference of x is  [ 0.09026182 -0.00874916]
# difference of x is  [ 0.1528219  -0.01450385]
# difference of x is  [ 0.09018731 -0.00874289]
# difference of x is  [ 0.15286124 -0.01450825]
# difference of x is  [ 0.09012556 -0.00873798]
# difference of x is  [ 0.15285838 -0.01450826]
# difference of x is  [ 0.09005904 -0.00873221]
# difference of x is  [ 0.15288222 -0.01451102]
# difference of x is  [ 0.08999217 -0.00872672]
# difference of x is  [ 0.15289819 -0.01451294]
# difference of x is  [ 0.08992839 -0.00872143]
# difference of x is  [ 0.15290856 -0.01451427]
# difference of x is  [ 0.08986259 -0.00871589]
# difference of x is  [ 0.1529268  -0.01451643]
# difference of x is  [ 0.08979666 -0.00871041]
# difference of x is  [ 0.15293932 -0.01451803]
# difference of x is  [ 0.08973265 -0.008705  ]
# difference of x is  [ 0.15295279 -0.01451975]
# difference of x is  [ 0.0896672  -0.00869955]
# difference of x is  [ 0.15296865 -0.01452164]
# difference of x is  [ 0.08959889 -0.00869387]
# difference of x is  [ 0.15298903 -0.014524  ]
# difference of x is  [ 0.08953345 -0.00868847]
# difference of x is  [ 0.15300441 -0.01452589]
# difference of x is  [ 0.08946764 -0.00868298]
# difference of x is  [ 0.15301943 -0.0145277 ]
# difference of x is  [ 0.08940291 -0.00867761]
# difference of x is  [ 0.15303302 -0.01452938]
# difference of x is  [ 0.08933806 -0.00867218]
# difference of x is  [ 0.15304875 -0.01453131]
# difference of x is  [ 0.08926892 -0.00866645]
# difference of x is  [ 0.15307271 -0.01453402]
# difference of x is  [ 0.08921075 -0.00866172]
# difference of x is  [ 0.15306723 -0.01453379]
# difference of x is  [ 0.0891397  -0.00865556]
# difference of x is  [ 0.15309942 -0.01453737]
# difference of x is  [ 0.08907461 -0.00865028]
# difference of x is  [ 0.15310943 -0.01453874]
# difference of x is  [ 0.08901441 -0.00864523]
# difference of x is  [ 0.15311337 -0.01453944]
# difference of x is  [ 0.08894324 -0.00863923]
# difference of x is  [ 0.15314567 -0.01454298]
# difference of x is  [ 0.08888161 -0.00863424]
# difference of x is  [ 0.15314722 -0.01454351]
# difference of x is  [ 0.0888139  -0.00862848]
# difference of x is  [ 0.15316808 -0.01454589]
# difference of x is  [ 0.08875096 -0.00862326]
# difference of x is  [ 0.15317678 -0.01454714]
# difference of x is  [ 0.08868134 -0.00861737]
# difference of x is  [ 0.15320313 -0.01455015]
# difference of x is  [ 0.0886209  -0.00861253]
# difference of x is  [ 0.15320337 -0.0145504 ]
# difference of x is  [ 0.08855331 -0.00860674]
# difference of x is  [ 0.15322769 -0.01455321]
# difference of x is  [ 0.08848941 -0.00860157]
# difference of x is  [ 0.1532377  -0.01455452]
# difference of x is  [ 0.08842278 -0.00859591]
# difference of x is  [ 0.15325403 -0.01455655]
# difference of x is  [ 0.08835459 -0.00859028]
# difference of x is  [ 0.15327704 -0.01455918]
# difference of x is  [ 0.08829558 -0.00858548]
# difference of x is  [ 0.15327299 -0.01455907]
# difference of x is  [ 0.08823037 -0.00857982]
# difference of x is  [ 0.15329301 -0.01456145]
# difference of x is  [ 0.0881623  -0.00857422]
# difference of x is  [ 0.15331197 -0.01456367]
# difference of x is  [ 0.08809626 -0.00856872]
# difference of x is  [ 0.15332699 -0.01456556]
# difference of x is  [ 0.08803225 -0.00856343]
# difference of x is  [ 0.1533345 -0.0145666]
# difference of x is  [ 0.08796287 -0.0085576 ]
# difference of x is  [ 0.15336442 -0.01456995]
# difference of x is  [ 0.08790398 -0.00855288]
# difference of x is  [ 0.15335536 -0.01456935]
# difference of x is  [ 0.08783591 -0.00854696]
# difference of x is  [ 0.15338528 -0.01457273]
# difference of x is  [ 0.08776975 -0.00854155]
# difference of x is  [ 0.15339768 -0.01457436]
# difference of x is  [ 0.08770812 -0.00853647]
# difference of x is  [ 0.15340173 -0.01457497]
# difference of x is  [ 0.08763897 -0.00853065]
# difference of x is  [ 0.15342855 -0.01457803]
# difference of x is  [ 0.08757734 -0.00852565]
# difference of x is  [ 0.1534276  -0.01457827]
# difference of x is  [ 0.0875119  -0.00852003]
# difference of x is  [ 0.15344751 -0.01458062]
# difference of x is  [ 0.08744693 -0.00851467]
# difference of x is  [ 0.15345633 -0.01458184]
# difference of x is  [ 0.08737743 -0.00850883]
# difference of x is  [ 0.15348244 -0.01458481]
# difference of x is  [ 0.0873152  -0.00850378]
# difference of x is  [ 0.15348423 -0.01458529]
# difference of x is  [ 0.08724892 -0.00849816]
# difference of x is  [ 0.15350437 -0.01458766]
# difference of x is  [ 0.08718359 -0.00849278]
# difference of x is  [ 0.15351462 -0.01458906]
# difference of x is  [ 0.08711672 -0.00848716]
# difference of x is  [ 0.15353453 -0.01459138]
# difference of x is  [ 0.08705258 -0.00848189]
# difference of x is  [ 0.15354335 -0.01459261]
# difference of x is  [ 0.08698916 -0.00847662]
# difference of x is  [ 0.1535511 -0.0145936]
# difference of x is  [ 0.08692193 -0.008471  ]
# difference of x is  [ 0.15356982 -0.0145959 ]
# difference of x is  [ 0.08685672 -0.00846557]
# difference of x is  [ 0.15358245 -0.01459754]
# difference of x is  [ 0.08679259 -0.00846022]
# difference of x is  [ 0.15359247 -0.01459885]
# difference of x is  [ 0.08672464 -0.00845456]
# difference of x is  [ 0.1536113  -0.01460108]
# difference of x is  [ 0.08666134 -0.0084494 ]
# difference of x is  [ 0.15361786 -0.01460202]
# difference of x is  [ 0.08659303 -0.0084436 ]
# difference of x is  [ 0.15364051 -0.0146047 ]
# difference of x is  [ 0.08653045 -0.00843852]
# difference of x is  [ 0.1536411  -0.01460503]
# difference of x is  [ 0.08646333 -0.00843277]
# difference of x is  [ 0.15366137 -0.01460749]
# difference of x is  [ 0.08639371 -0.00842703]
# difference of x is  [ 0.15368319 -0.01461005]
# difference of x is  [ 0.08633208 -0.00842205]
# difference of x is  [ 0.15368176 -0.01461015]
# difference of x is  [ 0.08626568 -0.00841633]
# difference of x is  [ 0.15370154 -0.0146125 ]
# difference of x is  [ 0.08620024 -0.00841103]
# difference of x is  [ 0.15371156 -0.01461381]
# difference of x is  [ 0.08613396 -0.00840545]
# difference of x is  [ 0.15372443 -0.0146155 ]
# difference of x is  [ 0.08606768 -0.00839995]
# difference of x is  [ 0.15374017 -0.01461739]
# difference of x is  [ 0.08600366 -0.00839467]
# difference of x is  [ 0.15374553 -0.01461825]
# difference of x is  [ 0.08593512 -0.00838884]
# difference of x is  [ 0.1537677  -0.01462089]
# difference of x is  [ 0.08587444 -0.00838394]
# difference of x is  [ 0.1537627  -0.01462068]
# difference of x is  [ 0.08580351 -0.00837778]
# difference of x is  [ 0.15379417 -0.01462426]
# difference of x is  [ 0.08573675 -0.00837246]
# difference of x is  [ 0.15380216 -0.01462538]
# difference of x is  [ 0.0856688  -0.00836677]
# difference of x is  [ 0.15382016 -0.01462751]
# difference of x is  [ 0.08560574 -0.00836159]
# difference of x is  [ 0.15382302 -0.01462811]
# difference of x is  [ 0.08553851 -0.00835591]
# difference of x is  [ 0.1538409  -0.01463026]
# difference of x is  [ 0.08547282 -0.00835048]
# difference of x is  [ 0.15385067 -0.01463166]
# difference of x is  [ 0.08540499 -0.00834482]
# difference of x is  [ 0.15386665 -0.01463356]
# difference of x is  [ 0.08533919 -0.00833939]
# difference of x is  [ 0.15387654 -0.01463491]
# difference of x is  [ 0.0852741  -0.00833396]
# difference of x is  [ 0.15388572 -0.01463615]
# difference of x is  [ 0.08520234 -0.00832793]
# difference of x is  [ 0.15391183 -0.01463917]
# difference of x is  [ 0.08514512 -0.0083233 ]
# difference of x is  [ 0.15389574 -0.01463791]
# difference of x is  [ 0.08507288 -0.008317  ]
# difference of x is  [ 0.15393019 -0.01464172]
# difference of x is  [ 0.0850116  -0.00831214]
# difference of x is  [ 0.15392232 -0.01464122]
# difference of x is  [ 0.08493638 -0.00830568]
# difference of x is  [ 0.15396106 -0.01464555]
# difference of x is  [ 0.0848794  -0.00830124]
# difference of x is  [ 0.15394104 -0.01464379]
# difference of x is  [ 0.08480418 -0.0082946 ]
# difference of x is  [ 0.153983   -0.01464845]
# difference of x is  [ 0.08474183 -0.00828978]
# difference of x is  [ 0.1539725 -0.0146477]
# difference of x is  [ 0.08467257 -0.00828373]
# difference of x is  [ 0.15399659 -0.01465051]
# difference of x is  [ 0.08460569 -0.00827835]
# difference of x is  [ 0.15400445 -0.01465161]
# difference of x is  [ 0.08453727 -0.00827262]
# difference of x is  [ 0.15401983 -0.01465351]
# difference of x is  [ 0.08447266 -0.00826728]
# difference of x is  [ 0.15402305 -0.01465419]
# difference of x is  [ 0.08440328 -0.00826141]
# difference of x is  [ 0.15404224 -0.01465648]
# difference of x is  [ 0.08433425 -0.0082557 ]
# difference of x is  [ 0.15405488 -0.01465813]
# difference of x is  [ 0.08427119 -0.00825054]
# difference of x is  [ 0.15405631 -0.01465858]
# difference of x is  [ 0.08419895 -0.00824442]
# difference of x is  [ 0.15408087 -0.01466141]
# difference of x is  [ 0.08413064 -0.00823888]
# difference of x is  [ 0.15409029 -0.01466271]
# difference of x is  [ 0.08406043 -0.008233  ]
# difference of x is  [ 0.15410936 -0.014665  ]
# difference of x is  [ 0.08400083 -0.00822811]
# difference of x is  [ 0.15409636 -0.01466407]
# difference of x is  [ 0.08392334 -0.00822139]
# difference of x is  [ 0.15413892 -0.01466871]
# difference of x is  [ 0.08386266 -0.00821671]
# difference of x is  [ 0.15412271 -0.01466745]
# difference of x is  [ 0.08378994 -0.00821029]
# difference of x is  [ 0.15415323 -0.01467091]
# difference of x is  [ 0.08372641 -0.00820528]
# difference of x is  [ 0.15414774 -0.01467061]
# difference of x is  [ 0.08365154 -0.00819887]
# difference of x is  [ 0.15418065 -0.01467435]
# difference of x is  [ 0.08358777 -0.00819384]
# difference of x is  [ 0.15417135 -0.01467373]
# difference of x is  [ 0.0835197  -0.00818792]
# difference of x is  [ 0.15418899 -0.0146759 ]
# difference of x is  [ 0.08344793 -0.008182  ]
# difference of x is  [ 0.15420628 -0.01467804]
# difference of x is  [ 0.08338499 -0.00817687]
# difference of x is  [ 0.15419984 -0.01467763]
# difference of x is  [ 0.0833112  -0.00817053]
# difference of x is  [ 0.15422845 -0.01468095]
# difference of x is  [ 0.08324695 -0.00816545]
# difference of x is  [ 0.1542232  -0.01468068]
# difference of x is  [ 0.08317268 -0.00815906]
# difference of x is  [ 0.15425205 -0.01468407]
# difference of x is  [ 0.08310688 -0.00815375]
# difference of x is  [ 0.15424788 -0.01468397]
# difference of x is  [ 0.08303297 -0.00814746]
# difference of x is  [ 0.15427375 -0.01468695]
# difference of x is  [ 0.08296514 -0.00814199]
# difference of x is  [ 0.15427876 -0.01468784]
# difference of x is  [ 0.08289397 -0.00813604]
# difference of x is  [ 0.15429509 -0.01468981]
# difference of x is  [ 0.0828259  -0.00813038]
# difference of x is  [ 0.1542989  -0.01469062]
# difference of x is  [ 0.08275461 -0.00812438]
# difference of x is  [ 0.15431535 -0.01469264]
# difference of x is  [ 0.08268559 -0.00811871]
# difference of x is  [ 0.15432453 -0.01469392]
# difference of x is  [ 0.08261395 -0.00811272]
# difference of x is  [ 0.15433967 -0.01469583]
# difference of x is  [ 0.08254516 -0.00810702]
# difference of x is  [ 0.15434408 -0.01469665]
# difference of x is  [ 0.08247399 -0.00810108]
# difference of x is  [ 0.15435934 -0.01469854]
# difference of x is  [ 0.08240569 -0.00809544]
# difference of x is  [ 0.1543634  -0.01469931]
# difference of x is  [ 0.08233392 -0.00808942]
# difference of x is  [ 0.1543777  -0.01470111]
# difference of x is  [ 0.08226418 -0.00808369]
# difference of x is  [ 0.1543833  -0.01470204]
# difference of x is  [ 0.08219123 -0.00807752]
# difference of x is  [ 0.15440321 -0.01470447]
# difference of x is  [ 0.08212304 -0.00807199]
# difference of x is  [ 0.15440512 -0.01470501]
# difference of x is  [ 0.08204949 -0.00806571]
# difference of x is  [ 0.15442264 -0.01470716]
# difference of x is  [ 0.08197629 -0.00805975]
# difference of x is  [ 0.15443635 -0.01470895]
# difference of x is  [ 0.08190417 -0.00805379]
# difference of x is  [ 0.15444767 -0.01471046]
# difference of x is  [ 0.08183825 -0.00804831]
# difference of x is  [ 0.15444398 -0.01471047]
# difference of x is  [ 0.08176088 -0.0080417 ]
# difference of x is  [ 0.15447545 -0.01471406]
# difference of x is  [ 0.08169568 -0.00803655]
# difference of x is  [ 0.15445948 -0.01471276]
# difference of x is  [ 0.08161724 -0.0080297 ]
# difference of x is  [ 0.15449667 -0.01471695]
# difference of x is  [ 0.08155072 -0.00802449]
# difference of x is  [ 0.15448403 -0.01471597]
# difference of x is  [ 0.08147323 -0.00801784]
# difference of x is  [ 0.15451407 -0.01471944]
# difference of x is  [ 0.08140385 -0.00801222]
# difference of x is  [ 0.15451193 -0.01471962]
# difference of x is  [ 0.08133006 -0.00800599]
# difference of x is  [ 0.1545291 -0.0147217]
# difference of x is  [ 0.0812552  -0.00799981]
# difference of x is  [ 0.15454042 -0.01472326]
# difference of x is  [ 0.08118403 -0.00799392]
# difference of x is  [ 0.15454817 -0.0147244 ]
# difference of x is  [ 0.08111012 -0.0079878 ]
# difference of x is  [ 0.15456164 -0.01472612]
# difference of x is  [ 0.08104241 -0.00798219]
# difference of x is  [ 0.15455616 -0.01472592]
# difference of x is  [ 0.08096075 -0.00797523]
# difference of x is  [ 0.15459251 -0.01473002]
# difference of x is  [ 0.08089387 -0.00797   ]
# difference of x is  [ 0.15457964 -0.01472909]
# difference of x is  [ 0.08081591 -0.00796324]
# difference of x is  [ 0.15460873 -0.01473244]
# difference of x is  [ 0.08074641 -0.00795768]
# difference of x is  [ 0.15460074 -0.014732  ]
# difference of x is  [ 0.08066654 -0.00795083]
# difference of x is  [ 0.15463185 -0.01473558]
# difference of x is  [ 0.08059943 -0.00794546]
# difference of x is  [ 0.1546166  -0.01473441]
# difference of x is  [ 0.08052003 -0.00793859]
# difference of x is  [ 0.15464652 -0.01473787]
# difference of x is  [ 0.08044767 -0.00793279]
# difference of x is  [ 0.15464544 -0.01473812]
# difference of x is  [ 0.08036935 -0.00792617]
# difference of x is  [ 0.1546675  -0.01474077]
# difference of x is  [ 0.08029878 -0.00792049]
# difference of x is  [ 0.15466356 -0.01474072]
# difference of x is  [ 0.0802238  -0.00791407]
# difference of x is  [ 0.15467417 -0.0147422 ]
# difference of x is  [ 0.08014393 -0.00790742]
# difference of x is  [ 0.15469801 -0.01474505]
# difference of x is  [ 0.08007109 -0.0079015 ]
# difference of x is  [ 0.1546942  -0.01474503]
# difference of x is  [ 0.07999742 -0.00789529]
# ...
# difference of x is  [ 0.07619905 -0.0076754 ]
# difference of x is  [ 0.14642072 -0.01392563]
# difference of x is  [ 0.07111704 -0.00704618]
# difference of x is  [ 0.16423595 -0.01577628]
# difference of x is  [ 0.07670712 -0.00774488]
# difference of x is  [ 0.1437881  -0.01365837]
# difference of x is  [ 0.07038844 -0.00695493]
# difference of x is  [ 0.16617143 -0.01598213]
# difference of x is  [ 0.07719886 -0.00781399]
# difference of x is  [ 0.14101493 -0.01337831]
# difference of x is  [ 0.06972563 -0.00686887]
# difference of x is  [ 0.1677922 -0.0161554]
# difference of x is  [ 0.07749164 -0.00786257]
# difference of x is  [ 0.13863957 -0.01313991]
# difference of x is  [ 0.06912732 -0.00679334]
# difference of x is  [ 0.16890371 -0.01627551]
# difference of x is  [ 0.07749712 -0.00788009]
# difference of x is  [ 0.13695085 -0.01297182]
# difference of x is  [ 0.06852651 -0.00672493]
# difference of x is  [ 0.16960037 -0.01635234]
# difference of x is  [ 0.07726562 -0.00787194]
# difference of x is  [ 0.13582706 -0.012861  ]
# difference of x is  [ 0.06784427 -0.0066553 ]
# difference of x is  [ 0.17015672 -0.01641492]
# difference of x is  [ 0.0769254  -0.00785289]
# difference of x is  [ 0.13487637 -0.01276791]
# difference of x is  [ 0.06708193 -0.00658034]
# difference of x is  [ 0.17070925 -0.0164778 ]
# difference of x is  [ 0.07653034 -0.00782937]
# difference of x is  [ 0.13391292 -0.01267385]
# difference of x is  [ 0.0662576  -0.00649993]
# difference of x is  [ 0.17126334 -0.01654127]
# difference of x is  [ 0.07608402 -0.00780192]
# difference of x is  [ 0.13290882 -0.01257599]
# difference of x is  [ 0.06536567 -0.00641335]
# difference of x is  [ 0.17181337 -0.01660477]
# difference of x is  [ 0.07557642 -0.00776955]
# difference of x is  [ 0.13186729 -0.01247473]
# difference of x is  [ 0.06438482 -0.00631876]
# difference of x is  [ 0.1723975  -0.01667246]
# difference of x is  [ 0.07501316 -0.00773346]
# difference of x is  [ 0.13073635 -0.01236487]
# difference of x is  [ 0.06332469 -0.00621643]
# difference of x is  [ 0.17296898 -0.01673952]
# difference of x is  [ 0.07436144 -0.00769007]
# difference of x is  [ 0.12958038 -0.01225292]
# difference of x is  [ 0.0621413  -0.00610324]
# difference of x is  [ 0.17358303 -0.01681183]
# difference of x is  [ 0.07363343 -0.00764152]
# difference of x is  [ 0.12831414 -0.01213051]
# difference of x is  [ 0.0608542  -0.00597993]
# difference of x is  [ 0.17418182 -0.01688335]
# difference of x is  [ 0.07279754 -0.00758429]
# difference of x is  [ 0.12699258 -0.01200299]
# difference of x is  [ 0.05940843 -0.00584241]
# difference of x is  [ 0.17482555 -0.01696055]
# difference of x is  [ 0.07185721 -0.00751972]
# difference of x is  [ 0.12552404 -0.01186145]
# difference of x is  [ 0.05781281 -0.00569051]
# difference of x is  [ 0.17545164 -0.0170369 ]
# difference of x is  [ 0.0707612  -0.00744265]
# difference of x is  [ 0.12399817 -0.01171475]
# difference of x is  [ 0.05600464 -0.00551958]
# difference of x is  [ 0.17612374 -0.01711947]
# difference of x is  [ 0.06951928 -0.00735516]
# difference of x is  [ 0.12228203 -0.01154998]
# difference of x is  [ 0.0539825  -0.00532821]
# difference of x is  [ 0.1767689  -0.01720035]
# difference of x is  [ 0.0680604  -0.00725028]
# difference of x is  [ 0.12049711 -0.01137916]
# difference of x is  [ 0.05166042 -0.00511006]
# difference of x is  [ 0.17747259 -0.01728914]
# difference of x is  [ 0.06639314 -0.00713046]
# difference of x is  [ 0.1184454  -0.01118287]
# difference of x is  [ 0.04905033 -0.00486428]
# difference of x is  [ 0.17810023 -0.01737133]
# difference of x is  [ 0.06441605 -0.00698509]
# difference of x is  [ 0.11633277 -0.01098149]
# difference of x is  [ 0.04598856 -0.00457823]
# difference of x is  [ 0.1788553  -0.01746923]
# difference of x is  [ 0.06214762 -0.00682008]
# difference of x is  [ 0.11379099 -0.01073896]
# difference of x is  [ 0.04255557 -0.00425589]
# difference of x is  [ 0.17939508 -0.01754533]
# difference of x is  [ 0.05941379 -0.00661461]
# difference of x is  [ 0.11132848 -0.0105054 ]
# difference of x is  [ 0.03837764 -0.00386846]
# difference of x is  [ 0.18036342 -0.01767049]
# difference of x is  [ 0.05631828 -0.00639113]
# difference of x is  [ 0.10777712 -0.01016658]
# difference of x is  [ 0.0339725  -0.00345139]
# difference of x is  [ 0.18028426 -0.01768144]
# difference of x is  [ 0.05240226 -0.00608103]
# difference of x is  [ 0.10568488 -0.00997142]
# difference of x is  [ 0.02767897 -0.00287982]
# difference of x is  [ 0.18292642 -0.01799365]
# difference of x is  [ 0.04809606 -0.00580638]
# difference of x is  [ 0.09810638 -0.00924452]
# difference of x is  [ 0.02363598 -0.00246068]
# difference of x is  [ 0.17707992 -0.01737061]
# difference of x is  [ 0.0412569 -0.0051296]
# difference of x is  [ 0.10599458 -0.01002438]
# difference of x is  [ 0.0076983  -0.00112863]
# difference of x is  [ 0.19915521 -0.01984014]
# difference of x is  [-1.7960243   0.94917214]
# difference of x is  [0.44643414 1.8304237 ]
# difference of x is  [ 0.17610657 -0.02789763]
# difference of x is  [ 0.19117796 -0.01794099]
# difference of x is  [ 0.18752253 -0.01758871]
# difference of x is  [ 0.186548   -0.01749472]
# difference of x is  [ 0.18508065 -0.01735733]
# difference of x is  [ 0.18368423 -0.01722623]
# difference of x is  [ 0.18228757 -0.01709511]
# difference of x is  [ 0.18091989 -0.01696669]
# difference of x is  [ 0.17958629 -0.01684151]
# difference of x is  [ 0.17829072 -0.01671993]
# difference of x is  [ 0.17703724 -0.01660221]
# difference of x is  [ 0.17582214 -0.0164881 ]
# difference of x is  [ 0.17464924 -0.01637806]
# difference of x is  [ 0.17351317 -0.01627137]
# difference of x is  [ 0.17241478 -0.01616827]
# difference of x is  [ 0.17135108 -0.01606842]
# difference of x is  [ 0.17032194 -0.01597183]
# difference of x is  [ 0.16932344 -0.01587809]
# difference of x is  [ 0.16835594 -0.01578728]
# difference of x is  [ 0.1674161  -0.01569905]
# difference of x is  [ 0.16650307 -0.01561332]
# difference of x is  [ 0.1656158 -0.0155301]
# difference of x is  [ 0.16475141 -0.01544892]
# difference of x is  [ 0.16390955 -0.01536991]
# difference of x is  [ 0.16308987 -0.01529303]
# difference of x is  [ 0.16228914 -0.01521784]
# difference of x is  [ 0.16150844 -0.01514459]
# difference of x is  [ 0.16074634 -0.01507305]
# difference of x is  [ 0.16000068 -0.01500307]
# difference of x is  [ 0.1592716  -0.01493464]
# difference of x is  [ 0.1585586  -0.01486775]
# difference of x is  [ 0.15785933 -0.01480214]
# difference of x is  [ 0.1571759  -0.01473794]
# difference of x is  [ 0.15650451 -0.01467503]
# difference of x is  [ 0.15584731 -0.01461328]
# difference of x is  [ 0.15520155 -0.0145527 ]
# difference of x is  [ 0.15456796 -0.01449323]
# difference of x is  [ 0.15394545 -0.01443485]
# difference of x is  [ 0.15333462 -0.01437752]
# difference of x is  [ 0.15273333 -0.01432107]
# difference of x is  [ 0.15214205 -0.01426561]
# difference of x is  [ 0.15156138 -0.01421114]
# difference of x is  [ 0.15098822 -0.01415734]
# difference of x is  [ 0.15042567 -0.01410455]
# difference of x is  [ 0.14987087 -0.01405253]
# difference of x is  [ 0.14932394 -0.01400115]
# difference of x is  [ 0.14878654 -0.01395078]
# difference of x is  [ 0.14825547 -0.01390092]
# difference of x is  [ 0.14773262 -0.01385186]
# difference of x is  [ 0.14721608 -0.01380345]
# difference of x is  [ 0.14670682 -0.01375558]
# difference of x is  [ 0.14620495 -0.01370853]
# difference of x is  [ 0.14570868 -0.01366198]
# difference of x is  [ 0.14521873 -0.01361598]
# difference of x is  [ 0.14473581 -0.0135707 ]
# difference of x is  [ 0.14425695 -0.01352577]
# difference of x is  [ 0.14378524 -0.01348153]
# difference of x is  [ 0.1433196 -0.0134378]
# difference of x is  [ 0.14285755 -0.01339451]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_295768/1868305846.py in <module>
#      27     J_prev = J
#      28
# ---> 29     k, K = backward_pass(x, u, x_target, Q, R)
#      30
#      31     x, u = forward_pass(x, x0, u)
#
# /tmp/ipykernel_295768/3059847344.py in backward_pass(x, u, x_target, Q, R)
#      21
#      22     for t in reversed(range(T)):
# ---> 23         A = fd_rk4_x(x[t], u[t])
#      24         # print("A is ", A)
#      25         B = fd_rk4_u(x[t], u[t])
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/api.py in jacfun(*args, **kwargs)
#     808     if not has_aux:
#     809       pushfwd: Callable = partial(_jvp, f_partial, dyn_args)
# --> 810       y, jac = vmap(pushfwd, out_axes=(None, -1))(_std_basis(dyn_args))
#     811     else:
#     812       pushfwd: Callable = partial(_jvp, f_partial, dyn_args, has_aux=True)
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1212     axis_size_ = (axis_size if axis_size is not None else
#    1213                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1214     out_flat = batching.batch(
#    1215         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1216         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     190
#     191     try:
# --> 192       ans = self.f(*args, **dict(self.params, **kwargs))
#     193     except:
#     194       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/api.py in _jvp(fun, primals, tangents, has_aux)
#    1928   if not has_aux:
#    1929     flat_fun, out_tree = flatten_fun_nokwargs(fun, tree_def)
# -> 1930     out_primals, out_tangents = ad.jvp(flat_fun).call_wrapped(ps_flat, ts_flat)
#    1931     out_tree = out_tree()
#    1932     return (tree_unflatten(out_tree, out_primals),
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     190
#     191     try:
# --> 192       ans = self.f(*args, **dict(self.params, **kwargs))
#     193     except:
#     194       # Some transformations yield from inside context managers, so we have to
#
# /tmp/ipykernel_295768/3606139947.py in fd_rk4(x, u)
#       8     s3 = f( x+ dt/2*s2, u )
#       9     s4 = f( x+ dt*s3, u )
# ---> 10     x_next = x + dt/6 * ( s1 + 2 * s2 + 2 * s3 + s4 )
#      11
#      12     return x_next
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py in op(self, *args)
#     737 def _forward_operator_to_aval(name):
#     738   def op(self, *args):
# --> 739     return getattr(self.aval, f"_{name}")(self, *args)
#     740   return op
#     741
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py in deferring_binary_op(self, other)
#     263     args = (other, self) if swap else (self, other)
#     264     if isinstance(other, _accepted_binop_types):
# --> 265       return binary_op(*args)
#     266     # Note: don't use isinstance here, because we don't want to raise for
#     267     # subclasses, e.g. NamedTuple objects that may override operators.
#
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/pjit.py in cache_miss(*args, **kwargs)
#     325   @api_boundary
#     326   def cache_miss(*args, **kwargs):
# --> 327     outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     328         jit_info, *args, **kwargs)
#     329     executable = _read_most_recent_pjit_call_executable(jaxpr)
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/pjit.py in _python_pjit_helper(jit_info, *args, **kwargs)
#     183
#     184   try:
# --> 185     out_flat = pjit_p.bind(*args_flat, **params)
#     186   except pxla.DeviceAssignmentMismatchError as e:
#     187     fails, = e.args
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2832     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833                  else axis_main.with_cur_sublevel())
# -> 2834     return self.bind_with_trace(top_trace, args, params)
#    2835
#    2836
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     418   def bind_with_trace(self, trace, args, params):
#     419     with pop_level(trace.level):
# --> 420       out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     422
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/interpreters/ad.py in process_primitive(self, primitive, tracers, params)
#     313       msg = f"Differentiation rule for '{primitive}' not implemented"
#     314       raise NotImplementedError(msg)
# --> 315     primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     316     if primitive.multiple_results:
#     317       return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    1970   _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    1971   _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 1972   outputs = pjit_p.bind(
#    1973       *primals_in, *_filter_zeros_in(tangents_in),
#    1974       jaxpr=jaxpr_jvp,
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2832     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833                  else axis_main.with_cur_sublevel())
# -> 2834     return self.bind_with_trace(top_trace, args, params)
#    2835
#    2836
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     418   def bind_with_trace(self, trace, args, params):
#     419     with pop_level(trace.level):
# --> 420       out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     422
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     431       frame = self.get_frame(vals_in, dims_in)
#     432       batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 433       val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     434     src = source_info_util.current()
#     435     if primitive.multiple_results:
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/pjit.py in _pjit_batcher(insert_axis, spmd_axis_name, axis_size, axis_name, main_type, vals_in, dims_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline)
#    1893     raise NotImplementedError
#    1894
# -> 1895   vals_out = pjit_p.bind(
#    1896     *vals_in,
#    1897     jaxpr=new_jaxpr,
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/core.py in bind(self, *args, **params)
#    2832     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2833                  else axis_main.with_cur_sublevel())
# -> 2834     return self.bind_with_trace(top_trace, args, params)
#    2835
#    2836
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     418   def bind_with_trace(self, trace, args, params):
#     419     with pop_level(trace.level):
# --> 420       out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     422
#
# ~/anaconda3/envs/py310/lib/python3.10/site-packages/jax/_src/core.py in full_raise(self, val)
#     509     self.sublevel = sublevel
#     510
# --> 511   def full_raise(self, val) -> TracerType:
#     512     if not isinstance(val, Tracer):
#     513       # This check is only applied to non-Tracers, because the hasattr() is
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(4,1, figsize=(6, 9))
ax[0].plot(J_list)
ax[0].set_ylabel('J(x,u)')
ax[0].set_xlabel('step')
ax[0].set_title('Cost Function Evolution')

ax[1].plot(abs(J_list[1:]-J_list[:-1]))
ax[1].set_xlabel('step')
ax[1].set_title(' J-J_{prev} ')
ax[1].set_yscale('log')

ax[2].plot(x[:,0])
ax[2].set_xlabel('step')
ax[2].set_title(' x[0] ')

ax[3].plot(x[:,0])
ax[3].plot(np.ones_like(x[:,1]) * x_target[0], linestyle="--")
ax[3].set_xlabel('step')
ax[3].set_title(' x[0] Comparison with Reference ')

fig.subplots_adjust(hspace=1)
plt.show()

# %%
x0 - x_target
# Out:
# Array([0.00999999, 0.        ], dtype=float32)

# %% [markdown]
# ## 3. Implementation based on Trajax
